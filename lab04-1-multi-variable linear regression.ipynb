# %% [markdown]
# # Hypothesis using matrix

# %% [markdown]
# | $$X_1$$ | $$X_1$$ | $$X_3$$ | $$Y$$ |
# |:-------:|:-------:|:-------:|:-----:|
# |73       |80       |75       |152    |
# |93       |88       |93       |185    |
# |89       |91       |90       |180    |
# |96       |98       |100      |196    |
# |73       |66       |70       |142    |

# %% [markdown]
# $$ H(x_{1},x_{2},x_{3}) = x_{1}w_{1} + x_{2}w_{2} + x_{3}w_{3}
# $$

# %% [markdown]
# ## python codes :

# %%
import tensorflow as tf
x1_data = [73., 93., 89., 96., 73.]
x2_data = [80., 88., 91., 98., 66.]
x3_data = [75., 93., 90., 100., 70.]

y_data = [152., 185., 180., 196., 142.]

# %%
x1 = tf.placeholder(tf.float32)
x2 = tf.placeholder(tf.float32)
x3 = tf.placeholder(tf.float32)

Y = tf.placeholder(tf.float32)

# %%
w1 = tf.Variable(tf.random_normal([1]), name='weight1')
w2 = tf.Variable(tf.random_normal([1]), name='weight2')
w3 = tf.Variable(tf.random_normal([1]), name='weight3')
b = tf.Variable(tf.random_normal([1]), name='bias')

# %% [markdown]
# ### hypothesis
# $$ H(x_{1},x_{2},x_{3}) = x_{1}w_{1} + x_{2}w_{2} + x_{3}w_{3}
# $$

# %%
hypothesis = x1 * w1 + x2 * w2 + x3 * w3 + b
print(hypothesis)
# Out:
# Tensor("add_14:0", dtype=float32)

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %%
# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train],
                                   feed_dict={x1: x1_data, x2: x2_data, x3: x3_data, Y: y_data})
    if step % 10 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)
# Out:
# 0 Cost:  1226.61
# Prediction:
#  [ 188.71263123  217.09707642  218.86349487  238.30435181  163.33016968]
# 10 Cost:  23.7354
# Prediction:
#  [ 158.01478577  180.23576355  182.52511597  198.73455811  135.22155762]
# 20 Cost:  23.5988
# Prediction:
#  [ 157.90338135  180.13699341  182.4095459   198.61045837  135.1534729 ]
# 30 Cost:  23.4739
# Prediction:
#  [ 157.884552    180.14938354  182.40356445  198.60571289  135.17019653]
# 40 Cost:  23.3497
# Prediction:
#  [ 157.86605835  180.16207886  182.39793396  198.60133362  135.18710327]
# 50 Cost:  23.2263
# Prediction:
#  [ 157.84762573  180.17474365  182.39233398  198.59698486  135.20397949]
# 60 Cost:  23.1034
# Prediction:
#  [ 157.82923889  180.18736267  182.38671875  198.59262085  135.22080994]
# 70 Cost:  22.9812
# Prediction:
#  [ 157.81091309  180.19996643  182.38113403  198.58828735  135.2375946 ]
# 80 Cost:  22.8597
# Prediction:
#  [ 157.79263306  180.21253967  182.37557983  198.58395386  135.2543335 ]
# 90 Cost:  22.7388
# ...

# %% [markdown]
# # Matrix
#
# 학습데이터가 많아질 시 스파게티 코드가 되기때문에
# 매트릭스 사용
#
# $
# \left({\begin{array}{c} x_{1} & x_{2} & x_{3} \end{array}}\right)
# *
# \left(\begin{array}{c} w_{1} \\ w_{2} \\ w_{3} \end{array}\right)
# =
# \left({\begin{array}{c} x_{1}w_{1} + x_{2}w_{2} + x_{3}w_{3} \end{array}}\right)
# $
#
# $H(X) = XW$

# %% [markdown]
# ## python codes :

# %%
import tensorflow as tf
x_data = [[73., 80., 75.], [93., 88., 93.],
         [89., 91., 90.], [96., 98., 100.], [73., 66., 70.]]

y_data = [[152.], [185.], [180.], [196.], [142.]]

# %%
X = tf.placeholder(tf.float32, shape=[None, 3]) #None = data의 갯수가 얼마든지 들어올수 있음
Y = tf.placeholder(tf.float32, shape=[None, 1])

# %%
W = tf.Variable(tf.random_normal([3, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# %% [markdown]
# ### hypothesis
# $$ H(x_{1},x_{2},x_{3}) = x_{1}w_{1} + x_{2}w_{2} + x_{3}w_{3}
# $$

# %%
hypothesis = tf.matmul(X, W) + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=1e-5)
train = optimizer.minimize(cost)

# %%
# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, hy_val, _ = sess.run([cost, hypothesis, train],
                                   feed_dict={X: x_data, Y: y_data})
    if step % 10 == 0:
        print(step, "Cost: ", cost_val, "\nPrediction:\n", hy_val)
# Out:
# 0 Cost:  7990.88
# Prediction:
#  [[ 76.23345947]
#  [ 86.47385406]
#  [ 87.75216675]
#  [ 96.32037354]
#  [ 64.14930725]]
# 10 Cost:  11.7769
# Prediction:
#  [[ 155.24002075]
#  [ 181.45767212]
#  [ 181.32899475]
#  [ 198.22415161]
#  [ 136.60317993]]
# 20 Cost:  11.6452
# Prediction:
#  [[ 155.46653748]
#  [ 181.75370789]
#  [ 181.6083374 ]
#  [ 198.52931213]
#  [ 136.83409119]]
# 30 Cost:  11.587
# Prediction:
#  [[ 155.45472717]
#  [ 181.76319885]
#  [ 181.60540771]
#  [ 198.52709961]
#  [ 136.84643555]]
# 40 Cost:  11.529
# Prediction:
#  [[ 155.44221497]
#  [ 181.77180481]
#  [ 181.60163879]
#  [ 198.52394104]
#  [ 136.858078  ]]
# 50 Cost:  11.4713
# Prediction:
#  [[ 155.42976379]
#  [ 181.78041077]
#  [ 181.59785461]
#  [ 198.52079773]
#  [ 136.8697052 ]]
# 60 Cost:  11.4139
# Prediction:
#  [[ 155.41731262]
#  [ 181.78897095]
#  [ 181.59410095]
#  [ 198.51765442]
#  [ 136.88130188]]
# 70 Cost:  11.3569
# Prediction:
#  [[ 155.40492249]
#  [ 181.79750061]
# ...
